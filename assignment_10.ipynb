# %% [markdown]
# # **Assignment 10**

# %%
# core
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# ml
from sklearn import datasets as ds
from sklearn import linear_model as lm
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.model_selection import train_test_split

#plotly or other graphing library

# %%
# Load datasets here once and assign to variables iris and boston

#iris = 
iris = ds.load_iris()
#boston = 
boston = ds.load_boston()

# %% [markdown]
# **Q1**
#
# **Data set: Iris**
#
# * Return the first 5 rows of the data including the feature names as column headings in a DataFrame and a
# separate Python list containing target names

# %%
X = pd.DataFrame(iris['data'])
y = iris['target']

#iris_features = pd.DataFrame(iris['data'])

X.columns = iris['feature_names']

X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print(iris['target_names'])
# Out:
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# **Q2**
#
# **Data set: Iris**
#
# * Fit the Iris dataset into a kNN model with neighbors=5 and predict the category of observations passed in
# argument new_observations. Return back the target names of each prediction (and not their encoded values,
#  i.e. return setosa instead of 0).

# %%
knn = KNN(n_neighbors=5)
knn.fit(X, y)

new_observations = knn.predict(X)

iris['target_names'][new_observations]
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'virginica', 'versicolor', 'virginica', 'versicolor',
# ...

# %% [markdown]
# **Q3** 15 pts
#
# **Data set: Iris**
#
# * Split the Iris dataset into a train / test model with the split ratio between the two established by the function parameter split.
#
# * Fit KNN with the training data with number of neighbors equal to the function parameter neighbors
#
# * Generate and return back an accuracy score using the test data that was split out

# %%
(X_train, X_test, y_train, y_test) = train_test_split(X, y, test_size=0.3, random_state=45)

knn = KNN(n_neighbors = 5)
knn.fit(X_train, y_train)

knn_score = knn.score(X, y)
knn_score
# Out:
# 0.9666666666666667

# %% [markdown]
# **Q4**
#
# **Data set: Iris**
#
# * Generate an overfitting / underfitting curve of kNN each of the testing and training accuracy performance scores series for a range of neighbor (k) values from 1 to 30 and plot the curves (number of neighbors is x-axis, performance score is y-axis on the chart).

# %%
dfscores = pd.DataFrame(columns=['k', 'accuracy'])

for k in range(1, 31):
    (X_train, X_test, y_train, y_test) = train_test_split(X, y, test_size=0.3, random_state=45)
    
    knn = KNN(n_neighbors = k)
    knn.fit(X_train, y_train)
    
    knn_score = knn.score(X_test, y_test)
    df = pd.DataFrame({'k': k, 'accuracy': knn_score}, columns=dfscores.columns, index=[k])
    dfscores = pd.concat([dfscores, df], axis=0)
    
plt.scatter(data=dfscores, x='k', y='accuracy')
plt.xlabel('k nearest neighbors')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# **Q5** 10 pts
#
# **Data set: Boston**
#
#
# * Load sklearn's Boston data into a DataFrame (only the data and feature_name as column names)
#
# * Load sklearn's Boston target values into a separate DataFrame
#
# * Return back the average of AGE, average of the target (median value of homes or MEDV), and the target as NumPy values

# %%
X1 = pd.DataFrame(boston['data'], columns=boston['feature_names'])
y1 = pd.DataFrame(boston['target'], columns=['homes'])

print("average of AGE",np.mean(X1['AGE']))
print("median value of homes",np.median(y1['homes']))

arr_y1 = np.array(y1)
print(arr_y1)
# Out:
# average of AGE 68.57490118577078
# median value of homes 21.2
# [[24. ]
#  [21.6]
#  [34.7]
#  [33.4]
#  [36.2]
#  [28.7]
#  [22.9]
#  [27.1]
#  [16.5]
#  [18.9]
#  [15. ]
#  [18.9]
#  [21.7]
#  [20.4]
#  [18.2]
#  [19.9]
#  [23.1]
#  [17.5]
#  [20.2]
#  [18.2]
#  [13.6]
#  [19.6]
#  [15.2]
#  [14.5]
#  [15.6]
#  [13.9]
#  [16.6]
#  [14.8]
#  [18.4]
#  [21. ]
#  [12.7]
#  [14.5]
#  [13.2]
#  [13.1]
#  [13.5]
#  [18.9]
#  [20. ]
#  [21. ]
#  [24.7]
#  [30.8]
#  [34.9]
#  [26.6]
#  [25.3]
#  [24.7]
#  [21.2]
#  [19.3]
#  [20. ]
#  [16.6]
#  [14.4]
#  [19.4]
#  [19.7]
#  [20.5]
#  [25. ]
#  [23.4]
#  [18.9]
#  [35.4]
#  [24.7]
#  [31.6]
#  [23.3]
#  [19.6]
#  [18.7]
#  [16. ]
#  [22.2]
#  [25. ]
#  [33. ]
#  [23.5]
#  [19.4]
#  [22. ]
#  [17.4]
#  [20.9]
#  [24.2]
#  [21.7]
#  [22.8]
#  [23.4]
#  [24.1]
#  [21.4]
#  [20. ]
#  [20.8]
#  [21.2]
#  [20.3]
#  [28. ]
#  [23.9]
#  [24.8]
#  [22.9]
#  [23.9]
#  [26.6]
#  [22.5]
#  [22.2]
#  [23.6]
#  [28.7]
#  [22.6]
#  [22. ]
#  [22.9]
# ...

# %% [markdown]
# **Q6**
#
# **Data set: Boston**
#
# * In the Boston dataset, the feature PTRATIO refers to pupil teacher ratio.
#
# * Using a matplotlib scatter plot, plot MEDV median value of homes as y-axis and PTRATIO as x-axis
#
# * Return back PTRATIO as a NumPy array

# %%
plt.scatter(x=X1['PTRATIO'], y=y1['homes'])
plt.xlabel('Pupil-teacher ratio')
plt.ylabel('Median value of homes')
plt.show()

arr_X1 = np.array(X1['PTRATIO'])
arr_X1
# Out:
# array([15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2,
#        15.2, 15.2, 21. , 21. , 21. , 21. , 21. , 21. , 21. , 21. , 21. ,
#        21. , 21. , 21. , 21. , 21. , 21. , 21. , 21. , 21. , 21. , 21. ,
#        21. , 21. , 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9,
#        17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1,
#        17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1,
#        16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7,
#        18.7, 18.7, 18.7, 19. , 19. , 19. , 19. , 18.5, 18.5, 18.5, 18.5,
#        17.8, 17.8, 17.8, 17.8, 18.2, 18.2, 18.2, 18. , 18. , 18. , 18. ,
#        18. , 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9,
#        20.9, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 19.1,
#        19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 21.2, 21.2, 21.2, 21.2, 21.2,
#        21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 14.7,
# ...

# %% [markdown]
# **Q7**
#
# **Data set: Boston**
#
# * Create a regression model for MEDV / PTRATIO and display a chart showing the regression line using matplotlib
#
#
# * Use np.linspace() to generate prediction X values from min to max PTRATIO
#
# * Return back the regression prediction space and regression predicted values
#
# * Make sure to labels axes appropriately

# %%
lreg = lm.LinearRegression()
lreg.fit(arr_X1.reshape(-1, 1), arr_y1.reshape(-1, 1))

X1_test = np.linspace(np.min(arr_X1), np.max(arr_X1)).reshape(-1, 1)

y1_pred = lreg.predict(X1_test)

# %%
X1_test
# Out:
# array([[12.6       ],
#        [12.79183673],
#        [12.98367347],
#        [13.1755102 ],
#        [13.36734694],
#        [13.55918367],
#        [13.75102041],
#        [13.94285714],
#        [14.13469388],
#        [14.32653061],
#        [14.51836735],
#        [14.71020408],
#        [14.90204082],
#        [15.09387755],
#        [15.28571429],
#        [15.47755102],
#        [15.66938776],
#        [15.86122449],
#        [16.05306122],
#        [16.24489796],
#        [16.43673469],
#        [16.62857143],
#        [16.82040816],
#        [17.0122449 ],
#        [17.20408163],
#        [17.39591837],
#        [17.5877551 ],
#        [17.77959184],
#        [17.97142857],
#        [18.16326531],
#        [18.35510204],
#        [18.54693878],
#        [18.73877551],
#        [18.93061224],
#        [19.12244898],
#        [19.31428571],
#        [19.50612245],
#        [19.69795918],
#        [19.88979592],
#        [20.08163265],
#        [20.27346939],
# ...

# %%
y1_pred
# Out:
# array([[35.16421874],
#        [34.75039328],
#        [34.33656781],
#        [33.92274235],
#        [33.50891688],
#        [33.09509142],
#        [32.68126595],
#        [32.26744049],
#        [31.85361502],
#        [31.43978956],
#        [31.02596409],
#        [30.61213863],
#        [30.19831316],
#        [29.7844877 ],
#        [29.37066224],
#        [28.95683677],
#        [28.54301131],
#        [28.12918584],
#        [27.71536038],
#        [27.30153491],
#        [26.88770945],
#        [26.47388398],
#        [26.06005852],
#        [25.64623305],
#        [25.23240759],
#        [24.81858212],
#        [24.40475666],
#        [23.99093119],
#        [23.57710573],
#        [23.16328026],
#        [22.7494548 ],
#        [22.33562933],
#        [21.92180387],
#        [21.5079784 ],
#        [21.09415294],
#        [20.68032747],
#        [20.26650201],
#        [19.85267654],
#        [19.43885108],
#        [19.02502561],
#        [18.61120015],
# ...

# %%
plt.scatter(arr_X1, arr_y1)
plt.plot(X1_test, y1_pred, color='red', linewidth=2)
plt.xlabel('Pupil-teacher ratio')
plt.ylabel('Median value of homes')
plt.show()
