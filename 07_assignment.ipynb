# %% [markdown]
# <a href="https://colab.research.google.com/github/data602sps/assignments/blob/master/05_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 7**
#
# # **Weeks 8 & 9 - Pandas**
# * In this homework assignment, you will explore and analyze a public dataset of your choosing. Since this assignment is “open-ended” in nature, you are free to expand upon the requirements below. However, you must meet the minimum requirments as indicated in each section.
#
# * You must use Pandas as the **primary tool** to process your data.
#
# * The preferred method for this analysis is in a .ipynb file. Feel free to use whichever platform of your choosing.
#  * https://www.youtube.com/watch?v=inN8seMm7UI (Getting started with Colab).
#
# * Your data should need some "work", or be considered "dirty".  You must show your skills in data cleaning/wrangling.
#
# ### **Some data examples:**
# •	https://www.data.gov/
#
# •	https://opendata.cityofnewyork.us/
#
# •	https://datasetsearch.research.google.com/
#
# •	https://archive.ics.uci.edu/ml/index.php
#
# ### **Resources:**
#
# •	https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
#
# •	https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
#
# ### **Headings or comments**
# **You are required to make use of comments, or headings for each section.  You must explain what your code is doing, and the results of running your code.**  Act as if you were giving this assignment to your manager - you must include clear and descriptive information for each section.
#
# ### **You may work as a group or indivdually on this assignment.**

# %% [markdown]
# # Introduction
#
# In this section, please describe the dataset you are using.  Include a link to the source of this data.  You should also provide some explanation on why you choose this dataset.

# %% [markdown]
# I will be using "Open Parking and Camera Violations" dataset from  https://opendata.cityofnewyork.us/. This dataset contains Open Parking and Camera Violations issued by the City of New York. I chose this dataset to have an overview the different types of violations and see if there is any pattern in this data.

# %% [markdown]
# ______________
# # Data Exploration
# Import your dataset into your .ipynb, create dataframes, and explore your data.
#
# Include:
#
# * Summary statistics means, medians, quartiles,
# * Missing value information
# * Any other relevant information about the dataset.

# %%
import pandas as pd

# %%
df1 = pd.read_csv("https://data.cityofnewyork.us/resource/nc67-uf89.csv")
df1
# Out:
#         plate state license_type  summons_number  issue_date violation_time  \
# 0     JCK7759    NY          PAS      4014507397  07/21/2020         06:51P
# 1     JKL3196    NY          PAS      4014518267  07/22/2020         05:18P
# 2    T774013C    NY          OMT      4014533360  07/14/2020         12:00P
# 3      Y10FJY    NJ          PAS      4706974732  09/11/2020         10:08A
# 4      4DZ721    MA          PAS      8713719361  02/26/2019         01:24P
# ..        ...   ...          ...             ...         ...            ...
# 995   93495JT    NY          COM      8500240428  03/09/2020         06:42P
# 996  T471877C    NY          OMT      4667865210  10/04/2019         08:01A
# 997   FHD4893    NY          PAS      8714226030  03/19/2019         01:13P
# 998   29069JY    NY          COM      8720004138  01/07/2019         05:22P
# 999   HEG4943    NY          PAS      8713759190  02/27/2019         04:31P
#
# ...

# %% [markdown]
# ### Summary

# %%
df1.describe()
# Out:
#        summons_number  fine_amount  penalty_amount  interest_amount  \
# count    1.000000e+03   821.000000      821.000000       821.000000
# mean     7.269431e+09    67.752741       10.182704         0.678660
# std      1.641203e+09    29.863078       18.837320         3.524489
# min      1.344526e+09    35.000000        0.000000         0.000000
# 25%      5.097586e+09    45.000000        0.000000         0.000000
# 50%      8.250550e+09    60.000000        0.000000         0.000000
# 75%      8.487669e+09    95.000000       10.000000         0.000000
# max      8.783366e+09   115.000000       60.000000        53.110000
#
#        reduction_amount  payment_amount  amount_due    precinct
# count        821.000000      821.000000       821.0  821.000000
# mean          11.404495       67.209610         0.0   52.462850
# std           27.612564       43.742873         0.0   45.915433
# min            0.000000        0.000000         0.0    0.000000
# ...

# %% [markdown]
# ### Missing value

# %%
df2 = df1.dropna()
df2
# Out:
#        plate state license_type  summons_number  issue_date violation_time  \
# 9    HZM8269    NY          PAS      8674042752  01/25/2019         05:37A
# 29   HRF9827    NY          PAS      8586881995  04/05/2018         07:31P
# 30   HRF9827    NY          PAS      8586882008  04/05/2018         07:32P
# 97   JYB3675    PA          PAS      8586883165  04/13/2018         07:57P
# 202  GTJ6874    NY          PAS      7536652355  01/09/2016         02:25P
# 383   XEKK39    NJ          PAS      8673437180  11/14/2018         12:33P
# 418  GXI5960    NY          SRF      8649171035  04/27/2018         11:16A
# 503  EKE8705    NY          PAS      7536666147  04/12/2016         02:02P
# 579  GFR3986    NY          PAS      8649186105  06/11/2018         10:40A
# 589  HZZ5611    NY          PAS      8674072586  08/28/2018         08:05P
# 635  HCN1024    NY          PAS      8681561728  10/18/2018         11:36A
# ...

# %% [markdown]
# # Data Wrangling
# Create a subset of your original data and perform the following.
#
# 1. Modify multiple column names.

# %%
df1.rename(columns = {'summons_number':'summons_id', 'violation':'violation_type'}, inplace = True)
df1
# Out:
#         plate state license_type  summons_id  issue_date violation_time  \
# 0     88650MG    NY          COM  8097521738  05/26/2016         10:25A
# 1      AR982A    NJ          PAS  8097521982  05/26/2016         04:33P
# 2     61452MA    NY          COM  5099048936  10/18/2017         03:31P
# 3     7AV1881    MD          PAS  8097522305  05/28/2016         08:50A
# 4      XDRS98    NJ          PAS  8097522317  05/28/2016         09:06A
# ..        ...   ...          ...         ...         ...            ...
# 995   GZK4613    NY          PAS  4638140476  10/10/2017         03:57P
# 996   HET5103    NY          PAS  8478098653  05/16/2018         12:18P
# 997   GEV4361    NY          PAS  4664120175  08/27/2019         06:34A
# 998  T634819C    NY          PAS  1422488690  06/20/2017         11:38A
# 999   BNC9263    NY          PAS  4638140464  10/10/2017         03:56P
#
#                      violation_type judgment_entry_date  fine_amount  \
# ...

# %% [markdown]
# 2. Look at the structure of your data – are any variables improperly coded? Such as strings or characters? Convert to correct structure if needed.

# %%
# Add a letter M at the end of the value in violation_time

df1['violation_time'] = df1['violation_time'].apply(lambda x: f"{x}M")
df1
# Out:
#         plate state license_type  summons_id  issue_date violation_time  \
# 0     88650MG    NY          COM  8097521738  05/26/2016        10:25AM
# 1      AR982A    NJ          PAS  8097521982  05/26/2016        04:33PM
# 2     61452MA    NY          COM  5099048936  10/18/2017        03:31PM
# 3     7AV1881    MD          PAS  8097522305  05/28/2016        08:50AM
# 4      XDRS98    NJ          PAS  8097522317  05/28/2016        09:06AM
# ..        ...   ...          ...         ...         ...            ...
# 995   GZK4613    NY          PAS  4638140476  10/10/2017        03:57PM
# 996   HET5103    NY          PAS  8478098653  05/16/2018        12:18PM
# 997   GEV4361    NY          PAS  4664120175  08/27/2019        06:34AM
# 998  T634819C    NY          PAS  1422488690  06/20/2017        11:38AM
# 999   BNC9263    NY          PAS  4638140464  10/10/2017        03:56PM
#
#                      violation_type judgment_entry_date  fine_amount  \
# ...

# %% [markdown]
# 3. Fix missing and invalid values in data.

# %%
# Fix the value for issuing_agency when value if TRAFFIC 

df1.loc[df1['issuing_agency'] == 'TRAFFIC', 'issuing_agency'] = 'DEPARTMENT OF TRAFFIC'
df1
# Out:
#         plate state license_type  summons_number  issue_date violation_time  \
# 0     HLD5441    NY          PAS      8731389843  11/19/2021         11:07A
# 1     KHN8238    NY          PAS      8731389946  11/22/2021         08:40A
# 2     GWE2161    NY          PAS      4020471630  10/28/2021         04:49P
# 3     JPU4061    NY          PAS      8731389934  11/22/2021         08:40A
# 4    T800379C    NY          OMT      8731389831  11/19/2021         11:06A
# ..        ...   ...          ...             ...         ...            ...
# 995    F16MXS    NJ          PAS      4021676442  12/18/2021         09:57P
# 996   KLH4440    NY          PAS      4021676454  12/18/2021         09:57P
# 997   KTC1520    NY          PAS      4021676478  12/19/2021         06:08A
# 998   KNW7306    NY          PAS      4758684789  11/30/2021         11:28A
# 999   KEL1490    NY          PAS      4021676466  12/19/2021         06:05A
#
# ...

# %% [markdown]
# 4. Create new columns based on existing columns or calculations.

# %%
# Create new column violation_date_time = issue_date + violation_time
df1["violation_date_time"] = df1["issue_date"] +' ' + df1["violation_time"]
df1
# Out:
#         plate state license_type  summons_number  issue_date violation_time  \
# 0     HLD5441    NY          PAS      8731389843  11/19/2021         11:07A
# 1     KHN8238    NY          PAS      8731389946  11/22/2021         08:40A
# 2     GWE2161    NY          PAS      4020471630  10/28/2021         04:49P
# 3     JPU4061    NY          PAS      8731389934  11/22/2021         08:40A
# 4    T800379C    NY          OMT      8731389831  11/19/2021         11:06A
# ..        ...   ...          ...             ...         ...            ...
# 995    F16MXS    NJ          PAS      4021676442  12/18/2021         09:57P
# 996   KLH4440    NY          PAS      4021676454  12/18/2021         09:57P
# 997   KTC1520    NY          PAS      4021676478  12/19/2021         06:08A
# 998   KNW7306    NY          PAS      4758684789  11/30/2021         11:28A
# 999   KEL1490    NY          PAS      4021676466  12/19/2021         06:05A
#
# ...

# %% [markdown]
# 5. Drop column(s) from your dataset.

# %%
# Drop column issue_date and violation_time (index 4 and 5)

df1.drop(df1.columns[[4,5]], axis = 1, inplace = True)
df1
# Out:
#         plate state license_type  summons_number  \
# 0     HLD5441    NY          PAS      8731389843
# 1     KHN8238    NY          PAS      8731389946
# 2     GWE2161    NY          PAS      4020471630
# 3     JPU4061    NY          PAS      8731389934
# 4    T800379C    NY          OMT      8731389831
# ..        ...   ...          ...             ...
# 995    F16MXS    NJ          PAS      4021676442
# 996   KLH4440    NY          PAS      4021676454
# 997   KTC1520    NY          PAS      4021676478
# 998   KNW7306    NY          PAS      4758684789
# 999   KEL1490    NY          PAS      4021676466
#
#                           violation judgment_entry_date  fine_amount  \
# 0        NO PARKING-STREET CLEANING                 NaN         65.0
# 1        NO PARKING-STREET CLEANING                 NaN         65.0
# 2                BUS LANE VIOLATION                 NaN         50.0
# 3        NO PARKING-STREET CLEANING                 NaN         65.0
# ...

# %% [markdown]
# 6. Drop a row(s) from your dataset.

# %%
#Drop row 1
df3 = df1.drop(1)
df3
# Out:
#         plate state license_type  summons_number  \
# 0     HLD5441    NY          PAS      8731389843
# 2     GWE2161    NY          PAS      4020471630
# 3     JPU4061    NY          PAS      8731389934
# 4    T800379C    NY          OMT      8731389831
# 5     KSM4770    NY          PAS      4020471629
# ..        ...   ...          ...             ...
# 995    F16MXS    NJ          PAS      4021676442
# 996   KLH4440    NY          PAS      4021676454
# 997   KTC1520    NY          PAS      4021676478
# 998   KNW7306    NY          PAS      4758684789
# 999   KEL1490    NY          PAS      4021676466
#
#                           violation judgment_entry_date  fine_amount  \
# 0        NO PARKING-STREET CLEANING                 NaN         65.0
# 2                BUS LANE VIOLATION                 NaN         50.0
# 3        NO PARKING-STREET CLEANING                 NaN         65.0
# 4        NO PARKING-STREET CLEANING                 NaN         65.0
# ...

# %% [markdown]
# 7. Sort your data based on multiple variables.

# %%
# Sort based on state ascending and fine_amount descending
df4 = df2.sort_values(["state", "fine_amount"], ascending = (True, False))
df4
# Out:
#         plate state license_type  summons_id  issue_date violation_time  \
# 67    GGM6990    NY          PAS  8326514408  06/24/2016        11:40AM
# 108   HMV4289    NY          PAS  8536397822  09/05/2017        01:36PM
# 205   GTA4220    NY          PAS  8192017096  10/23/2016        02:11PM
# 550   66897MJ    NY          COM  8504058475  03/03/2017        08:25AM
# 931   HCG2579    NY          PAS  8521533070  07/10/2017        01:29PM
# 203   13825MK    NY          COM  8486861469  01/04/2017        09:59AM
# 276  T693511C    NY          OMT  8486865384  01/17/2017        07:57AM
# 551   GDG9163    NY          PAS  8504058736  03/04/2017        10:52AM
# 571   GTB1919    NY          PAS  8486875675  02/23/2017        09:33AM
# 410   FWF2221    NY          PAS  7027870447  10/11/2014        06:21PM
# 586  T760694C    NY          OMT  8664039045  09/10/2018        07:19AM
# 349   GWY8666    NY          PAS  5099876262  12/10/2017        10:19PM
# ...

# %% [markdown]
# 8. Filter your data based on some condition.

# %%
#Get all data for license_type= PAS
df5 = df2[(df2.license_type == 'PAS')]
df5
# Out:
#        plate state license_type  summons_number  issue_date violation_time  \
# 132  JMV8148    NY          PAS      4695358888  06/19/2020         07:47P
# 164  GVH5337    NY          PAS      4658502926  07/15/2019         10:37A
# 166  JCE8431    NY          PAS      4695359546  06/19/2020         07:52P
# 202  JKJ4181    NY          PAS      4012826463  01/08/2020         04:03P
# 391  KJL3667    NY          PAS      4021673337  12/18/2021         07:04P
# 433  JRN6705    NY          PAS      4705268301  08/28/2020         12:35P
# 473  GSA2495    NY          PAS      4021673714  12/18/2021         07:17P
# 474  KLL6236    NY          PAS      4737693431  06/28/2021         07:02P
# 481  GEX6540    NY          PAS      4698196115  07/09/2020         01:46P
# 484  KEF9540    NY          PAS      4754020030  10/26/2021         04:03P
# 628  JPX1011    NY          PAS      4695369710  06/19/2020         09:12P
# ...

# %% [markdown]
# 9. Convert all the string values to upper or lower cases in one column.

# %%
df5["violation"] =df5["violation"].str.lower()
df5
# Out:
#        plate state license_type  summons_number  issue_date violation_time  \
# 132  JMV8148    NY          PAS      4695358888  06/19/2020         07:47P
# 164  GVH5337    NY          PAS      4658502926  07/15/2019         10:37A
# 166  JCE8431    NY          PAS      4695359546  06/19/2020         07:52P
# 202  JKJ4181    NY          PAS      4012826463  01/08/2020         04:03P
# 391  KJL3667    NY          PAS      4021673337  12/18/2021         07:04P
# 433  JRN6705    NY          PAS      4705268301  08/28/2020         12:35P
# 473  GSA2495    NY          PAS      4021673714  12/18/2021         07:17P
# 474  KLL6236    NY          PAS      4737693431  06/28/2021         07:02P
# 481  GEX6540    NY          PAS      4698196115  07/09/2020         01:46P
# 484  KEF9540    NY          PAS      4754020030  10/26/2021         04:03P
# 628  JPX1011    NY          PAS      4695369710  06/19/2020         09:12P
# ...

# %% [markdown]
# 10. Check whether numeric values are present in a given column of your dataframe.

# %%
df5.license_type.str.isnumeric()
# Out:
# 132    False
# 164    False
# 166    False
# 202    False
# 391    False
# 433    False
# 473    False
# 474    False
# 481    False
# 484    False
# 628    False
# 707    False
# 772    False
# 804    False
# 874    False
# 966    False
# Name: license_type, dtype: bool

# %% [markdown]
# 11. Group your dataset by one column, and get the mean, min, and max values by group.
#   * Groupby()
#    * agg() or .apply()

# %%
df6 = df2.groupby('state').agg({'payment_amount': ['mean', 'min', 'max']})
df6
# Out:
#       payment_amount
#                 mean     min     max
# state
# FL        175.990000  175.99  175.99
# IN        125.000000  125.00  125.00
# NJ        175.930000  175.21  176.29
# NY        127.338125    0.00  223.07
# PA        175.390000  175.39  175.39

# %% [markdown]
# 12. Group your dataset by two columns and then sort the aggregated results within the groups.

# %%
df7 = df2.groupby(['state','license_type']).agg({'payment_amount': ['mean', 'min', 'max']}).sort_values(['state','license_type'], ascending=[True,False])
df7
# Out:
#                    payment_amount
#                              mean     min     max
# state license_type
# FL    PAS              175.990000  175.99  175.99
# IN    PAS              125.000000  125.00  125.00
# NJ    PAS              175.930000  175.21  176.29
# NY    SRF              127.240000  127.24  127.24
#       PAS              127.344667    0.00  223.07
# PA    PAS              175.390000  175.39  175.39

# %% [markdown]
# **You are free (and should) to add on to these questions.  Please clearly indicate in your assignment your answers to these questions.**

# %% [markdown]
# # Conclusions
#
# After exploring your dataset, provide a short summary of what you noticed from this dataset.  What would you explore further with more time?

# %% [markdown]
# We see that New york has the highest payment amount, Florida has higher payment amounts on average.
